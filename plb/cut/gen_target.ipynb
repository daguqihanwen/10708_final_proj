# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
print(os.environ['CUDA_VISIBLE_DEVICES'])
os.environ['CUDA_VISIBLE_DEVICES']='0'

from plb.cut.sample_utils import init_env
env, state = init_env()
# Out:
# 0
# [Taichi] mode=release
# [Taichi] preparing sandbox at /tmp/taichi-nh18_vnt
# [Taichi] version 0.7.26, llvm 10.0.0, commit e37bdb5e, linux, python 3.7.11
# [I 09/24/21 19:28:35.079 2273322] [shell.py:_shell_pop_print@35] Graphical python shell detected, using wrapped sys.stdout
# [Taichi] Starting on arch=cuda
# [Tina] version 0.1.1
# [Tina] Taichi properties hacked
# pimirives: num primitive: 2
# Building primitive
# action:
#   dim: 3
#   scale: (0.015, 0.015, 0.015)
# collision_group: [0.0, 0.0, 0.0]
# color: (0.8, 0.8, 0.8)
# friction: 0.0
# h: (0.15, 0.15)
# init_pos: (0.5, 0.3, 0.5)
# init_rot: (1.0, 0.0, 0.0, 0.0)
# lower_bound: (0.0, 0.0, 0.0)
# prot: (1.0, 0.0, 0.0, 0.58)
# shape: Knife
# size: (0.025, 0.2, 0.06)
# upper_bound: (1.0, 1.0, 1.0)
# variations: None
# Building primitive
# action:
#   dim: 0
#   scale: ()
# collision_group: [0.0, 0.0, 0.0]
# color: (0.3, 0.3, 0.3)
# friction: 0.9
# h: (0.15, 0.15)
# init_pos: (0.3, 0.3, 0.3)
# init_rot: (1.0, 0.0, 0.0, 0.0)
# lower_bound: (0.0, 0.0, 0.0)
# prot: (1.0, 0.0, 0.0, 0.58)
# shape:
# upper_bound: (1.0, 1.0, 1.0)
# variations: None
# Building primitive
# action:
#   dim: 0
#   scale: ()
# collision_group: [0.0, 0.0, 0.0]
# color: (0.3, 0.3, 0.3)
# friction: 0.9
# init_pos: (0.3, 0.3, 0.3)
# init_rot: (1.0, 0.0, 0.0, 0.0)
# lower_bound: (0.0, 0.0, 0.0)
# shape:
# size: (0.025, 0.2, 0.06)
# upper_bound: (1.0, 1.0, 1.0)
# variations: None
# Building primitive
# action:
#   dim: 7
#   scale: (0.015, 0.015, 0.015, 0.0, 0.0, 0.0, 0.015)
# collision_group: [0.0, 0.0, 0.0]
# color: (0.8, 0.8, 0.8)
# friction: 10.0
# init_gap: 0.2
# init_pos: (0.5, 0.15, 0.5)
# init_rot: (0.707, 0.0, 0.707, 0.0)
# lower_bound: (0.0, 0.0, 0.0)
# maximal_gap: 0.2
# minimal_gap: 0.08
# round: 0
# shape: Gripper
# size: (0.015, 0.1, 0.06)
# upper_bound: (1.0, 1.0, 1.0)
# variations: None
# {'init_pos': (0.5, 0.12, 0.5), 'width': (0.2, 0.08, 0.08), 'color': 100, 'n_particles': 5000}
# Initialize Tina Renderer
# bake_size: 6
# cam_center: (0.5, 0.4, 0.5)
# cam_phi: -1.0
# cam_radius: 1.0
# cam_theta: 0.0
# camera_pos: (0.5, 1.2, 4.0)
# camera_rot: (0.2, 0)
# dx: 0.006666666666666667
# image_res: (512, 512)
# light_direction: (0.0, 1.0, 1.0)
# max_num_particles: 1000000
# max_ray_depth: 2
# mesh: False
# name: tina
# sdf_threshold: 0.20720000000000002
# spp: 50
# target_res: (64, 64, 64)
# tina_img_res: 1024
# use_directional_light: True
# use_roulette: False
# voxel_res: (168, 168, 168)
# [Tina] Hint: MMB to orbit, Shift+MMB to pan, wheel to zoom
# {'init_pos': (0.5, 0.12, 0.5), 'width': (0.2, 0.08, 0.08), 'color': 100, 'n_particles': 5000}
# [W 09/24/21 19:29:09.758 2273322] [type_check.cpp:visit@100] [$69819] Local store may lose precision (target = i32, value = f32) at
# [W 09/24/21 19:29:09.758 2273322] [type_check.cpp:visit@101]
#   File "/home/hza/PlasticineLab/plb/engine/mpm_simulator.py", line 218, in grid_op
#     v_out = self.primitives.primitives[i].collide(f, I * self.dx, v_out, self.dt, self.grid_m[I])
#   File "/home/hza/anaconda3/envs/xingyu/lib/python3.7/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/hza/anaconda3/envs/xingyu/lib/python3.7/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/hza/PlasticineLab/plb/engine/primitive/primitives.py", line 355, in collide
#     v_out1 = self.collide2(f, grid_pos, v_out, dt, mass, -1)
#   File "/home/hza/anaconda3/envs/xingyu/lib/python3.7/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/hza/anaconda3/envs/xingyu/lib/python3.7/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/hza/PlasticineLab/plb/engine/primitive/primitives.py", line 378, in collide2
#     flag = ti.cast(normal_component < 0 and ti.sqrt(grid_v_t.dot(grid_v_t)) > 1e-30, self.dtype)
#   File "/home/hza/anaconda3/envs/xingyu/lib/python3.7/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/hza/anaconda3/envs/xingyu/lib/python3.7/site-packages/taichi/lang/impl.py", line 202, in maybe_transform_ti_func_call_to_stmt
#     return ti_func(*args, **kwargs)
#   File "/home/hza/anaconda3/envs/xingyu/lib/python3.7/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/hza/anaconda3/envs/xingyu/lib/python3.7/site-packages/taichi/lang/ops.py", line 135, in wrapped
#     return imp_foo(a, b)
#
# [W 09/24/21 19:29:09.758 2273322] [type_check.cpp:visit@100] [$72886] Local store may lose precision (target = i32, value = f32) at
# [W 09/24/21 19:29:09.758 2273322] [type_check.cpp:visit@101]
#   File "/home/hza/PlasticineLab/plb/engine/mpm_simulator.py", line 218, in grid_op
#     v_out = self.primitives.primitives[i].collide(f, I * self.dx, v_out, self.dt, self.grid_m[I])
#   File "/home/hza/anaconda3/envs/xingyu/lib/python3.7/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/hza/anaconda3/envs/xingyu/lib/python3.7/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/hza/PlasticineLab/plb/engine/primitive/primitives.py", line 356, in collide
#     v_out2 = self.collide2(f, grid_pos, v_out1, dt, mass, 1)
#   File "/home/hza/anaconda3/envs/xingyu/lib/python3.7/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/hza/anaconda3/envs/xingyu/lib/python3.7/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/hza/PlasticineLab/plb/engine/primitive/primitives.py", line 378, in collide2
#     flag = ti.cast(normal_component < 0 and ti.sqrt(grid_v_t.dot(grid_v_t)) > 1e-30, self.dtype)
#   File "/home/hza/anaconda3/envs/xingyu/lib/python3.7/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/hza/anaconda3/envs/xingyu/lib/python3.7/site-packages/taichi/lang/impl.py", line 202, in maybe_transform_ti_func_call_to_stmt
#     return ti_func(*args, **kwargs)
#   File "/home/hza/anaconda3/envs/xingyu/lib/python3.7/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/hza/anaconda3/envs/xingyu/lib/python3.7/site-packages/taichi/lang/ops.py", line 135, in wrapped
#     return imp_foo(a, b)

# %%
env.render('rgb', img_size=512)
# Out:
# array([[[0.07186487, 0.15073058, 0.23190144, 2.8348617 ],
#         [0.07186487, 0.15073058, 0.23190144, 2.83265102],
#         [0.07186487, 0.15073058, 0.23190144, 2.83044803],
#         ...,
#         [0.07186487, 0.15073058, 0.23190144, 2.83044803],
#         [0.07186487, 0.15073058, 0.23190144, 2.83265102],
#         [0.07186487, 0.15073058, 0.23190144, 2.8348617 ]],
#
#        [[0.07186487, 0.15073058, 0.23190144, 2.82586288],
#         [0.07186487, 0.15073058, 0.23190144, 2.8236559 ],
#         [0.07186487, 0.15073058, 0.23190144, 2.82145631],
#         ...,
#         [0.07186487, 0.15073058, 0.23190144, 2.82145631],
#         [0.07186487, 0.15073058, 0.23190144, 2.8236559 ],
#         [0.07186487, 0.15073058, 0.23190144, 2.82586288]],
#
#        [[0.07186487, 0.15073058, 0.23190144, 2.81690991],
#         [0.07186487, 0.15073058, 0.23190144, 2.81470662],
#         [0.07186487, 0.15073058, 0.23190144, 2.81251055],
#         ...,
#         [0.07186487, 0.15073058, 0.23190144, 2.81251055],
#         [0.07186487, 0.15073058, 0.23190144, 2.81470662],
#         [0.07186487, 0.15073058, 0.23190144, 2.81690991]],
#
#        ...,
#
#        [[0.07186487, 0.15073058, 0.23190144, 1.2349523 ],
#         [0.07186487, 0.15073058, 0.23190144, 1.23398638],
#         [0.07186487, 0.15073058, 0.23190144, 1.23302358],
#         ...,
#         [0.07186487, 0.15073058, 0.23190144, 1.23302358],
#         [0.07186487, 0.15073058, 0.23190144, 1.23398638],
#         [0.07186487, 0.15073058, 0.23190144, 1.2349523 ]],
#
#        [[0.07186487, 0.15073058, 0.23190144, 1.23446941],
#         [0.07186487, 0.15073058, 0.23190144, 1.23350531],
#         [0.07186487, 0.15073058, 0.23190144, 1.23254448],
#         ...,
#         [0.07186487, 0.15073058, 0.23190144, 1.23254448],
#         [0.07186487, 0.15073058, 0.23190144, 1.23350531],
#         [0.07186487, 0.15073058, 0.23190144, 1.23446941]],
#
#        [[0.07186487, 0.15073058, 0.23190144, 1.23399076],
#         [0.07186487, 0.15073058, 0.23190144, 1.23302859],
#         [0.07186487, 0.15073058, 0.23190144, 1.23206949],
#         ...,
#         [0.07186487, 0.15073058, 0.23190144, 1.23206949],
#         [0.07186487, 0.15073058, 0.23190144, 1.23302859],
#         [0.07186487, 0.15073058, 0.23190144, 1.23399076]]])

# %%
from plb.cut.sample_utils import cut
from plb.cut.sample_utils import animate
env.set_state(**state)
images = list(cut(env, state, 0, filename='array', slide=True))
animate(images, 'xx.webm')
# Out:
# animating xx.webm
# Moviepy - Building video xx.webm.
# Moviepy - Writing video xx.webm
# Moviepy - Done !
# Moviepy - video ready xx.webm
# <video controls  >
#  <source src="data:video/webm;base64,..." type="video/webm">
#  Your browser does not support the video tag.
#  </video>

# %%
import numpy as np
import copy

def cut(state, cut_loc, slide_a, slide_b):
    ns = copy.deepcopy(state)
    flag = ns['state'][0][:, 0] <= cut_loc
    ns['state'][0][flag, 0] -= slide_a
    ns['state'][0][np.logical_not(flag), 0] += slide_b
    return ns, flag

def move_cluster(state, flag, dx, dz, dy=0):
    # need to move forward..
    new_state = copy.deepcopy(state)
    mean = new_state['state'][0][flag].mean(axis=0)
    new_state['state'][0][flag] += np.array([dx, mean[1] + dy, dz]) - mean
    return new_state

# %%
#env.renderer.update_camera((0.5, 0.1, 0.6), 1.0, -0.75, 0.75)
env.set_state(state)
"""
env.primitives[0].set_state(0, np.array([0.5, 0.35, 0.5, 1., 0., 0., 0.]))
env.primitives[1].set_state(0, np.array([0.5, 0.2, 0.5, 0.707, 0., 0.707, 0., 0.2]))
env.primitives[0].box.size[None] = (0.025, 0.2, 0.06)
state = env.get_state()
"""
print(env.primitives[0].box.size)

def generate(state):
    # sample two which are far away ..
    def rand(a, b):
        return np.random.random() * (b-a) + a

    state = copy.deepcopy(state)
    width = np.array([rand(0.2, 0.24), 0.08, rand(0.04, 0.08)])
    state['state'][0] = (np.random.random((len(state['state'][0]), 3)) * 2 - 1) * (0.5 * width) + np.array([0.5, 0.0669, 0.5])

    trajs = []
    da = db = 0.
    if np.random.randint(2):
        da = rand(0.1, 0.13)
    else:
        db = rand(0.1, 0.13)
    #cut = (np.random.random() * 2 - 1) * 0.75
    cut_loc = rand(0.48, 0.52)
    cutted, flag = cut(state, cut_loc, da, db)

    def sample_target():
        # make sure that it is moved away ..
        y = rand(0.3, 0.35) * (np.random.randint(2)*2 - 1) + 0.5
        x = rand(0.3, 0.7)
        return (x, y)

    trajs.append([state, cutted])

    while True:
        a = sample_target()
        b = sample_target()
        if np.linalg.norm(np.array(a) - np.array(b)) >= 0.3:
            break

    move1 = move_cluster(cutted, flag, *a)
    move2 = move_cluster(move1, np.logical_not(flag), *b)
    trajs.append([cutted, move2])
    trajs.append([move1, move2])
    return trajs

import numpy as np
import matplotlib.pyplot as plt

def visualize_traj(trajs):
    for sample in trajs:
        a, b = sample[:2]
        env.set_state(**a)
        img = env.render('rgb', img_size=512)
        env.set_state(**b)
        img2 = env.render('rgb', img_size=512)
        plt.imshow(np.concatenate((img, img2), 1)[..., :3])
        plt.show()

traj = generate(state)
visualize_traj(traj)
# Out:
# [0.025 0.2   0.06 ]

# %%
# !pwd
# Out:
# /home/hza/PlasticineLab/plb/cut

# %%
import torch
for idx, i in enumerate(traj):
    torch.save(traj[idx], f'sampled{idx}.pkl')

# %%
import tqdm
os.makedirs('dataset3', exist_ok=True)
for idx2 in tqdm.trange(1000):
    traj = generate(state)
    for idx, i in enumerate(traj):
        torch.save(traj[idx], f'dataset3/traj{idx2:04d}_{idx}.pkl')
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:29<00:00, 34.30it/s]

# %%
os.makedirs('data', exist_ok=True)
for i in range(4):
    os.makedirs(f'data/{i}', exist_ok=True)
    for j in range(i*70, (i+1)*70):
        traj = generate(state)
        for idx, k in enumerate(traj):
            torch.save(k, f'data/{i}/traj{j:04d}_{idx}.pkl')

# %%
raise NotImplementedError

a = torch.load('dataset3/traj0002_0.pkl')[0]
b = torch.load('dataset3/traj0002_0.pkl')[1]
torch.save([a, b], 'test.pkl')
print(a, b)

a = torch.load('dataset3/traj0002_0.pkl')[0]
b = torch.load('dataset3/traj0002_1.pkl')[1]
torch.save([a, b], 'test2.pkl')
# Out:
# {'state': [array([[0.5688541 , 0.03029123, 0.50746357],
#        [0.52823332, 0.10656807, 0.48642678],
#        [0.43519163, 0.04909143, 0.47352499],
#        ...,
#        [0.58068649, 0.06235912, 0.51481125],
#        [0.50605258, 0.1015523 , 0.48333081],
#        [0.39538474, 0.06989828, 0.48827778]]), array([[-0.00337464,  0.01843241, -0.00309275],
#        [-0.00634152,  0.01579595, -0.00241307],
#        [ 0.00410665,  0.02268436, -0.0020534 ],
#        ...,
#        [ 0.00140159,  0.02184484, -0.00352883],
#        [-0.01121698,  0.01353134, -0.0014822 ],
#        [-0.0044026 ,  0.01329166, -0.00369247]]), array([[[ 1.00102603e+00, -2.94379820e-03, -7.68423872e-03],
#         [ 4.39149374e-03,  1.00122833e+00,  6.94103725e-03],
#         [ 8.15120060e-03,  1.08960616e-04,  9.97232556e-01]],
#
#        [[ 1.00334883e+00, -5.80076175e-03, -7.05649937e-03],
#         [ 2.25213286e-03,  1.00475502e+00,  1.89252142e-02],
#         [ 9.56470612e-03, -3.09458654e-02,  1.00784469e+00]],
#
#        [[ 9.94446218e-01,  8.13645124e-03, -6.36812579e-03],
#         [-7.70878792e-03,  1.00082064e+00,  3.22747696e-03],
#         [ 8.29148293e-03, -4.63439478e-03,  1.00201237e+00]],
#
#        ...,
#
#        [[ 1.00637960e+00, -2.90512107e-03, -1.50187395e-03],
#         [ 2.70863343e-03,  9.83178258e-01, -1.15859874e-01],
#         [-1.24757481e-03,  1.30010858e-01,  9.92399871e-01]],
#
#        [[ 1.01027060e+00, -1.39868697e-02, -1.24038504e-02],
#         [ 1.81131549e-02,  1.01310992e+00, -5.11735789e-02],
#         [ 1.52409663e-02,  6.75998628e-02,  1.01002204e+00]],
#
#        [[ 1.00747931e+00,  5.27672283e-03, -6.60208706e-03],
#         [-9.74461436e-03,  9.88876343e-01, -8.07729214e-02],
#         [ 1.38128167e-02,  7.67985284e-02,  9.96912420e-01]]]), array([[[-0.27985862,  0.17931768, -0.11640995],
#         [-0.1076111 ,  0.1161971 , -0.00793285],
#         [ 0.05116794, -0.01648192,  0.06368342]],
#
#        [[-0.21920031,  0.08848372, -0.0379707 ],
#         [-0.12125196,  0.18290418, -0.00242696],
#         [ 0.03456859, -0.01891999,  0.02765779]],
#
#        [[-0.34374529,  0.18102022,  0.06547175],
#         [-0.14634331,  0.07866232, -0.01997487],
#         [-0.00474972,  0.02269692,  0.05907446]],
#
#        ...,
#
#        [[-0.142877  ,  0.30484506,  0.01376532],
#         [-0.40873688,  0.0929734 , -0.13100256],
#         [-0.03657   , -0.01245957,  0.02436154]],
#
#        [[-0.15089236, -0.09815319, -0.05657321],
#         [ 0.08301707,  0.11796962,  0.06363561],
#         [ 0.09010519, -0.07335468,  0.03420885]],
#
#        [[-0.14184165,  0.05675179, -0.06284221],
#         [-0.07955573,  0.15632725,  0.06498099],
#         [ 0.04475654, -0.04084713,  0.00462879]]]), array([0.5       , 0.30000001, 0.5       , 1.        , 0.        ,
#        0.        , 0.        ]), array([0.5       , 0.15000001, 0.5       , 0.70710677, 0.        ,
#        0.70710677, 0.        , 0.2       ])], 'softness': 0.0, 'is_copy': True} {'state': [array([[0.5688541 , 0.03029123, 0.50746357],
#        [0.52823332, 0.10656807, 0.48642678],
#        [0.33060563, 0.04909143, 0.47352499],
#        ...,
#        [0.58068649, 0.06235912, 0.51481125],
#        [0.50605258, 0.1015523 , 0.48333081],
#        [0.29079875, 0.06989828, 0.48827778]]), array([[-0.00337464,  0.01843241, -0.00309275],
#        [-0.00634152,  0.01579595, -0.00241307],
#        [ 0.00410665,  0.02268436, -0.0020534 ],
#        ...,
#        [ 0.00140159,  0.02184484, -0.00352883],
#        [-0.01121698,  0.01353134, -0.0014822 ],
#        [-0.0044026 ,  0.01329166, -0.00369247]]), array([[[ 1.00102603e+00, -2.94379820e-03, -7.68423872e-03],
#         [ 4.39149374e-03,  1.00122833e+00,  6.94103725e-03],
#         [ 8.15120060e-03,  1.08960616e-04,  9.97232556e-01]],
#
#        [[ 1.00334883e+00, -5.80076175e-03, -7.05649937e-03],
#         [ 2.25213286e-03,  1.00475502e+00,  1.89252142e-02],
#         [ 9.56470612e-03, -3.09458654e-02,  1.00784469e+00]],
#
#        [[ 9.94446218e-01,  8.13645124e-03, -6.36812579e-03],
#         [-7.70878792e-03,  1.00082064e+00,  3.22747696e-03],
#         [ 8.29148293e-03, -4.63439478e-03,  1.00201237e+00]],
#
#        ...,
#
#        [[ 1.00637960e+00, -2.90512107e-03, -1.50187395e-03],
#         [ 2.70863343e-03,  9.83178258e-01, -1.15859874e-01],
#         [-1.24757481e-03,  1.30010858e-01,  9.92399871e-01]],
#
#        [[ 1.01027060e+00, -1.39868697e-02, -1.24038504e-02],
#         [ 1.81131549e-02,  1.01310992e+00, -5.11735789e-02],
#         [ 1.52409663e-02,  6.75998628e-02,  1.01002204e+00]],
#
#        [[ 1.00747931e+00,  5.27672283e-03, -6.60208706e-03],
#         [-9.74461436e-03,  9.88876343e-01, -8.07729214e-02],
#         [ 1.38128167e-02,  7.67985284e-02,  9.96912420e-01]]]), array([[[-0.27985862,  0.17931768, -0.11640995],
#         [-0.1076111 ,  0.1161971 , -0.00793285],
#         [ 0.05116794, -0.01648192,  0.06368342]],
#
#        [[-0.21920031,  0.08848372, -0.0379707 ],
#         [-0.12125196,  0.18290418, -0.00242696],
#         [ 0.03456859, -0.01891999,  0.02765779]],
#
#        [[-0.34374529,  0.18102022,  0.06547175],
#         [-0.14634331,  0.07866232, -0.01997487],
#         [-0.00474972,  0.02269692,  0.05907446]],
#
#        ...,
#
#        [[-0.142877  ,  0.30484506,  0.01376532],
#         [-0.40873688,  0.0929734 , -0.13100256],
#         [-0.03657   , -0.01245957,  0.02436154]],
#
#        [[-0.15089236, -0.09815319, -0.05657321],
#         [ 0.08301707,  0.11796962,  0.06363561],
#         [ 0.09010519, -0.07335468,  0.03420885]],
#
#        [[-0.14184165,  0.05675179, -0.06284221],
#         [-0.07955573,  0.15632725,  0.06498099],
#         [ 0.04475654, -0.04084713,  0.00462879]]]), array([0.5       , 0.30000001, 0.5       , 1.        , 0.        ,
#        0.        , 0.        ]), array([0.5       , 0.15000001, 0.5       , 0.70710677, 0.        ,
#        0.70710677, 0.        , 0.2       ])], 'softness': 0.0, 'is_copy': True}

# %%
env.set_state(a)
img = env.render('rgb', img_size=512)
plt.imshow(img[:,:,:3])

# %%
env.set_state(b)
img = env.render('rgb', img_size=512)
plt.imshow(img[:,:,:3])

# %%
a = torch.load('sampled9/traj0000_2_1.pkl')
b = torch.load('dataset3/traj0000_1.pkl')[1]
torch.save([a['initial_state'], b], 'test3.pkl')
