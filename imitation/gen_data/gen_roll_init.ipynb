# %%
# %load_ext autoreload
# %autoreload 2
# %cd '~/carl/research/dev/PlasticineLab'
# %pwd
# %matplotlib inline
import matplotlib.pyplot as plt
import taichi as ti
import numpy as np
import cv2
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "2"
from plb.utils.visualization_utils import save_rgb
target_path = './datasets/0212_Roll/init'
if not os.path.exists(target_path):
    os.makedirs(target_path, exist_ok=True)
# Out:
# /home/jianrenw/carl/research/dev/PlasticineLab
# [Taichi] mode=release
# [Taichi] preparing sandbox at /tmp/taichi-yy1vs41c
# [Taichi] version 0.7.26, llvm 10.0.0, commit e37bdb5e, linux, python 3.8.11
# [I 02/13/22 13:59:19.229 910383] [shell.py:_shell_pop_print@35] Graphical python shell detected, using wrapped sys.stdout

# %%
import lzma
import pickle
import numpy as np
import os
from plb.utils.visualization_utils import save_numpy_as_gif
from imitation.env_spec import set_render_mode
np.random.seed(0)
from plb.envs.multitask_env import MultitaskPlasticineEnv
env = MultitaskPlasticineEnv(cfg_path=f'roll_official.yml', generating_cached_state=True)
set_render_mode(env, 'Roll-v1', 'mesh')
taichi_env = env.taichi_env

N1, N2 = 5, 5
xs = np.linspace(0.45, 0.55, N1)
zs = np.linspace(0.45, 0.55, N1)

def randomize_tool_state(cfg, box_min_x, pin_min_y):
    # No change on the init position of the box
#         pos = eval(cfg.PRIMITIVES[1]['init_pos'])
#         box_dist = np.random.rand() * 0.1 + 0.05
#         cfg.PRIMITIVES[1]['init_pos'] = (float(box_min_x + box_dist), pos[1], pos[2])

    pos = eval(cfg.PRIMITIVES[0]['init_pos'])
    height = np.random.rand() * 0.05
    # height = 0.01
    x_shift = np.random.rand() * 0.05 - 0.025
    z_shift = np.random.rand() * 0.05 - 0.025
    new_pos = (float(xs[i] + x_shift), float(pin_min_y+height), float(zs[k] + z_shift))
    # new_pos = (0.273, 0.2588, 0.5)
    print("tool pos:", new_pos)

    cfg.PRIMITIVES[0]['init_pos'] = new_pos
    print(new_pos)


def case1(cfg): # Sphere
    rs = np.linspace(0.10, 0.12, N2)
    # print('setting x pos {}, radius {}'.format(xs[i], fs[k]))
    pos = eval(cfg.SHAPES[0]['init_pos'])
#     cfg.SHAPES[0]['shape'] = 'sphere'
#     del cfg.SHAPES[0]['width']
    cfg.SHAPES[0]['radius'] = rs[k]
    new_pos = (xs[i], rs[k] + 0.04, zs[j])
    print('case1 new pos:', new_pos, 'radius:', rs[k]) 
    cfg.SHAPES[0]['init_pos'] = new_pos
    randomize_tool_state(cfg, 0, rs[k]*2+0.04+0.04)

def case11(cfg): # Sphere on initial place
    rs = np.linspace(0.04, 0.07, N)
    # print('setting x pos {}, radius {}'.format(xs[i], fs[k]))
    pos = eval(cfg.SHAPES[0]['init_pos'])
    cfg.SHAPES[0]['shape'] = 'sphere'
#     del cfg.SHAPES[0]['width']
    cfg.SHAPES[0]['radius'] = fs[k]
    new_pos = (pos[0], fs[k] + 0.03, pos[2])
    cfg.SHAPES[0]['init_pos'] = new_pos    

    randomize_tool_state(cfg, xs[i] + fs[k], fs[k]*2 + 0.1)
    
def case2(cfg): # Capsule
    rs = np.linspace(0.04, 0.06, N2)
    capsule_h = 0.2
    # print('setting x pos {}, radius {}, height {}'.format(xs[i], fs[k], capsule_h))

    pos = eval(cfg.SHAPES[0]['init_pos'])
    cfg.SHAPES[0]['shape'] = 'capsule'
    del cfg.SHAPES[0]['width']
    cfg.SHAPES[0]['radius'] = fs[k]
    cfg.SHAPES[0]['height'] = capsule_h
    new_pos = (pos[0], fs[k] + 0.01, pos[2])
    cfg.SHAPES[0]['init_pos'] = new_pos

    randomize_tool_state(cfg, xs[i] + fs[k], 0.19)

def case3(cfg):
    cfg.SHAPES[0]['shape'] = 'box'
    w = np.linspace(0.15, 0.25, N)
    h = np.linspace(0.03, 0.06, N)
    w_id, h_id = np.random.randint(0, N),  np.random.randint(0, N)
    pos = eval(cfg.SHAPES[0]['init_pos'])
    size = eval(cfg.SHAPES[0]['width'])
    new_pos = (xs[i], h[h_id] + 0.1, pos[2])
    new_size = (w[w_id], h[h_id], size[2])
    cfg.SHAPES[0]['init_pos'] = new_pos
    cfg.SHAPES[0]['width'] = new_size
    randomize_tool_state(cfg, xs[i] + w[w_id], 0.19)

def case4(cfg):
    rs = np.linspace(0.04, 0.07, N)
    # print('setting x pos {}, radius {}'.format(xs[i], fs[k]))
    pos = eval(cfg.SHAPES[0]['init_pos'])
#     cfg.SHAPES[0]['shape'] = 'sphere'
#     del cfg.SHAPES[0]['width']
    cfg.SHAPES[0]['radius'] = 0.07
    new_pos = (0.42, 0.11, 0.5)
    print('case1 new pos:', new_pos) 
    cfg.SHAPES[0]['init_pos'] = new_pos
    randomize_tool_state(cfg, xs[i] + fs[k], fs[k]*2+0.04)


target_id =0 
target_imgs = []
gifpath = os.path.join(target_path, 'vis_all.gif')
# for case_id, case in enumerate([case1, case11]):
for case_id, case in enumerate([case1]):
    for i in range(N1):
        for j in range(N1):
            for k in range(N2):
                env.reset(target_cfg_modifier=case)
                img = taichi_env.render(mode='rgb', img_size=128)
                state = taichi_env.get_state()
                state_name = os.path.join(target_path, f'state_{target_id}.xz')
                with lzma.open(state_name, 'wb') as f:
                    pickle.dump(state, f, protocol=4)
                save_rgb(os.path.join(target_path, f'state_{target_id}.png'), np.array(img[:, :, :3]).astype(np.float32))
                target_id += 1
                target_imgs.append(img)
save_numpy_as_gif(np.array(target_imgs)[:, :, :, :3], gifpath)
from IPython.display import Image
Image(gifpath)
# Out:
# Setting pykeops dir to  ~/.cache/pykeops_2080/
# [Taichi] Starting on arch=cuda
# [Tina] version 0.1.1
# [Tina] Taichi properties hacked
# pimirives: num primitive: 2
# Building primitive
# action:
#   dim: 6
#   scale: (0.7, 0.05, 0.005, 0.005, 0.0, 0.0)
# collision_group: [0.0, 0.0, 0.0]
# color: (1.0, 0.0, 0.0)
# friction: 0.9
# h: 0.23
# init_pos: (0.5, 0.25, 0.45)
# init_rot: (0.707, 0.707, 0.0, 0.0)
# lower_bound: (0.0, 0.04, 0.0)
# r: 0.04
# shape: RollingPinExt
# upper_bound: (1.0, 1.0, 1.0)
# variations: None
# Building primitive
# action:
#   dim: 0
#   scale: ()
# collision_group: [0.0, 0.0, 0.0]
# color: (0.5, 0.5, 0.5)
# friction: 5.0
# init_pos: (0.5, 0.02, 0.45)
# init_rot: (1.0, 0.0, 0.0, 0.0)
# lower_bound: (0.0, 0.0, 0.0)
# shape: Box
# size: (0.5, 0.02, 0.45)
# upper_bound: (1.0, 1.0, 1.0)
# variations: None
# Initialize Tina Renderer
# bake_size: 6
# cam_center: (0.5, 0.2, 0.45)
# cam_phi: -0.8
# cam_radius: 0.8
# cam_theta: 0.0
# camera_pos: (0.5, 1.2, 4.0)
# camera_rot: (0.2, 0)
# dx: 0.006666666666666667
# image_res: (128, 128)
# light_direction: (0.0, 1.0, 1.0)
# max_num_particles: 1000000
# max_ray_depth: 2
# mesh: False
# name: tina
# sdf_threshold: 0.20720000000000002
# spp: 50
# target_res: (64, 64, 64)
# tina_img_res: 512
# use_directional_light: True
# use_roulette: False
# voxel_res: (168, 168, 168)
# [Tina] Hint: MMB to orbit, Shift+MMB to pan, wheel to zoom
# Cached state path already exists. Deleting datasets/0212_Roll? [y/N]
#  y
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.45, 0.14, 0.45) radius: 0.1
# tool pos: (0.46075946831862097, 0.30744067519636625, 0.4551381688035822)
# (0.46075946831862097, 0.30744067519636625, 0.4551381688035822)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.45, 0.14500000000000002, 0.45) radius: 0.10500000000000001
# tool pos: (0.44618273996694524, 0.31724415914984483, 0.4822947056533328)
# (0.44618273996694524, 0.31724415914984483, 0.4822947056533328)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.45, 0.15, 0.45) radius: 0.11
# tool pos: (0.469588650039104, 0.3218793605631346, 0.5231831380250515)
# (0.469588650039104, 0.3218793605631346, 0.5231831380250515)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.45, 0.155, 0.45) radius: 0.11499999999999999
# tool pos: (0.4645862519041332, 0.32917207594128883, 0.5264447459876452)
# (0.4645862519041332, 0.32917207594128883, 0.5264447459876452)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.45, 0.16, 0.45) radius: 0.12
# tool pos: (0.4712798319146331, 0.34840222805469656, 0.5285518029098943)
# (0.4712798319146331, 0.34840222805469656, 0.5285518029098943)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.45, 0.14, 0.47500000000000003) radius: 0.1
# tool pos: (0.4260109198720163, 0.28435646498507705, 0.4666309922773969)
# (0.4260109198720163, 0.28435646498507705, 0.4666309922773969)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.45, 0.14500000000000002, 0.47500000000000003) radius: 0.10500000000000001
# tool pos: (0.46850060741234095, 0.32890783754749253, 0.49893091711163823)
# (0.46850060741234095, 0.32890783754749253, 0.49893091711163823)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.45, 0.15, 0.47500000000000003) radius: 0.11
# tool pos: (0.4480739681126466, 0.33995792821083615, 0.5140264588143227)
# (0.4480739681126466, 0.33995792821083615, 0.5140264588143227)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.45, 0.155, 0.47500000000000003) radius: 0.11499999999999999
# tool pos: (0.4569960510663762, 0.3159137212934466, 0.5071676643704524)
# (0.4569960510663762, 0.3159137212934466, 0.5071676643704524)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.45, 0.16, 0.47500000000000003) radius: 0.12
# tool pos: (0.4510924160875036, 0.36723344585247913, 0.5457330969995262)
# (0.4510924160875036, 0.36723344585247913, 0.5457330969995262)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.45, 0.14, 0.5) radius: 0.1
# tool pos: (0.46371168447171085, 0.29322778060523136, 0.44780751661082746)
# (0.46371168447171085, 0.29322778060523136, 0.44780751661082746)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.45, 0.14500000000000002, 0.5) radius: 0.10500000000000001
# tool pos: (0.42593949002181775, 0.3184216974434324, 0.4808817748537939)
# (0.42593949002181775, 0.3184216974434324, 0.4808817748537939)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.45, 0.15, 0.5) radius: 0.11
# tool pos: (0.4558466998437379, 0.33060478613612104, 0.5221874039257313)
# (0.4558466998437379, 0.33060478613612104, 0.5221874039257313)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.45, 0.155, 0.5) radius: 0.11499999999999999
# tool pos: (0.4429753950286893, 0.34409101495517413, 0.5218515976899671)
# (0.4429753950286893, 0.34409101495517413, 0.5218515976899671)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.45, 0.16, 0.5) radius: 0.12
# tool pos: (0.4280112735814635, 0.3548815597963632, 0.5583383357722834)
# (0.4280112735814635, 0.3548815597963632, 0.5583383357722834)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.45, 0.14, 0.525) radius: 0.1
# tool pos: (0.4355191280536921, 0.313531893480908, 0.43144631488274265)
# (0.4355191280536921, 0.313531893480908, 0.43144631488274265)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.45, 0.14500000000000002, 0.525) radius: 0.10500000000000001
# tool pos: (0.44318553854713116, 0.3057714175462092, 0.478509838520894)
# (0.44318553854713116, 0.3057714175462092, 0.478509838520894)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.45, 0.15, 0.525) radius: 0.11
# tool pos: (0.4744186919029613, 0.321930075673116, 0.4801022405374014)
# (0.4744186919029613, 0.321930075673116, 0.4801022405374014)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.45, 0.155, 0.525) radius: 0.11499999999999999
# tool pos: (0.4330654758942498, 0.32044383780474167, 0.53265541627327)
# (0.4330654758942498, 0.32044383780474167, 0.53265541627327)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.45, 0.16, 0.525) radius: 0.12
# tool pos: (0.4483155386428153, 0.3326645801269891, 0.5372212796000801)
# (0.4483155386428153, 0.3326645801269891, 0.5372212796000801)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.45, 0.14, 0.55) radius: 0.1
# tool pos: (0.4305187570582153, 0.287948479182276, 0.4578164794732637)
# (0.4305187570582153, 0.287948479182276, 0.4578164794732637)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.45, 0.14500000000000002, 0.55) radius: 0.10500000000000001
# tool pos: (0.4348291180840027, 0.2969091475674307, 0.46843625853304827)
# (0.4348291180840027, 0.2969091475674307, 0.46843625853304827)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.45, 0.15, 0.55) radius: 0.11
# tool pos: (0.4298550637896531, 0.34104966149239674, 0.5168972453749402)
# (0.4298550637896531, 0.34104966149239674, 0.5168972453749402)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.45, 0.155, 0.55) radius: 0.11499999999999999
# tool pos: (0.4738229732506698, 0.3148049203946981, 0.5234325600823851)
# (0.4738229732506698, 0.3148049203946981, 0.5234325600823851)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.45, 0.16, 0.55) radius: 0.12
# tool pos: (0.4552422759872523, 0.3688380544095168, 0.5619631789699151)
# (0.4552422759872523, 0.3688380544095168, 0.5619631789699151)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.47500000000000003, 0.14, 0.45) radius: 0.1
# tool pos: (0.4641403481288205, 0.28195938961271605, 0.43100982806065846)
# (0.4641403481288205, 0.28195938961271605, 0.43100982806065846)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.47500000000000003, 0.14500000000000002, 0.45) radius: 0.10500000000000001
# tool pos: (0.45593638594771224, 0.3048070098761072, 0.46589915896969886)
# (0.45593638594771224, 0.3048070098761072, 0.46589915896969886)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.47500000000000003, 0.15, 0.45) radius: 0.11
# tool pos: (0.4532073748174392, 0.3207131497257335, 0.509623605968501)
# (0.4532073748174392, 0.3207131497257335, 0.509623605968501)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.47500000000000003, 0.155, 0.45) radius: 0.11499999999999999
# tool pos: (0.4632694745469723, 0.3383300727103287, 0.526162402673335)
# (0.4632694745469723, 0.3383300727103287, 0.526162402673335)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.47500000000000003, 0.16, 0.45) radius: 0.12
# tool pos: (0.478797324777809, 0.324697025537922, 0.5714648098788108)
# (0.478797324777809, 0.324697025537922, 0.5714648098788108)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.47500000000000003, 0.14, 0.47500000000000003) radius: 0.1
# tool pos: (0.4833705189981841, 0.2959284476225662, 0.4315898931202196)
# (0.4833705189981841, 0.2959284476225662, 0.4315898931202196)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.47500000000000003, 0.14500000000000002, 0.47500000000000003) radius: 0.10500000000000001
# tool pos: (0.4644703046473601, 0.32581636020592825, 0.45915956810035585)
# (0.4644703046473601, 0.32581636020592825, 0.45915956810035585)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.47500000000000003, 0.15, 0.47500000000000003) radius: 0.11
# tool pos: (0.45100537730937473, 0.32932564674050413, 0.5164470014608682)
# (0.45100537730937473, 0.32932564674050413, 0.5164470014608682)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.47500000000000003, 0.155, 0.47500000000000003) radius: 0.11499999999999999
# tool pos: (0.48389082683981155, 0.3102347738096273, 0.5135003986596083)
# (0.48389082683981155, 0.3102347738096273, 0.5135003986596083)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.47500000000000003, 0.16, 0.47500000000000003) radius: 0.12
# tool pos: (0.49810942725587193, 0.3567597011061297, 0.5374376571759979)
# (0.49810942725587193, 0.3567597011061297, 0.5374376571759979)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.47500000000000003, 0.14, 0.5) radius: 0.1
# tool pos: (0.479602096563592, 0.3088078667208919, 0.4536125952895437)
# (0.479602096563592, 0.3088078667208919, 0.4536125952895437)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.47500000000000003, 0.14500000000000002, 0.5) radius: 0.10500000000000001
# tool pos: (0.4976374505758493, 0.3011540816320309, 0.4723562689308814)
# (0.4976374505758493, 0.3011540816320309, 0.4723562689308814)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.47500000000000003, 0.15, 0.5) radius: 0.11
# tool pos: (0.48497396376587526, 0.34232043362355635, 0.4898718475427567)
# (0.48497396376587526, 0.34232043362355635, 0.4898718475427567)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.47500000000000003, 0.155, 0.5) radius: 0.11499999999999999
# tool pos: (0.46982528704234927, 0.3506898909851238, 0.5440551598555581)
# (0.46982528704234927, 0.3506898909851238, 0.5440551598555581)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.47500000000000003, 0.16, 0.5) radius: 0.12
# tool pos: (0.49408676809274266, 0.3490636436317929, 0.5596265795038884)
# (0.49408676809274266, 0.3490636436317929, 0.5596265795038884)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.47500000000000003, 0.14, 0.525) radius: 0.1
# tool pos: (0.4750662190963352, 0.31626271399098205, 0.47280418173616123)
# (0.4750662190963352, 0.31626271399098205, 0.47280418173616123)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.47500000000000003, 0.14500000000000002, 0.525) radius: 0.10500000000000001
# tool pos: (0.47119275242790903, 0.32219950996148183, 0.48031966070639626)
# (0.47119275242790903, 0.32219950996148183, 0.48031966070639626)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.47500000000000003, 0.15, 0.525) radius: 0.11
# tool pos: (0.4650787408337275, 0.3009596599154667, 0.5080086768746342)
# (0.4650787408337275, 0.3009596599154667, 0.5080086768746342)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.47500000000000003, 0.155, 0.525) radius: 0.11499999999999999
# tool pos: (0.4809007714499421, 0.32450388036052213, 0.5214384350472884)
# (0.4809007714499421, 0.32450388036052213, 0.5214384350472884)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.47500000000000003, 0.16, 0.525) radius: 0.12
# tool pos: (0.46491411629780155, 0.3267737032111225, 0.5534982455350633)
# (0.46491411629780155, 0.3267737032111225, 0.5534982455350633)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.47500000000000003, 0.14, 0.55) radius: 0.1
# tool pos: (0.478716262442479, 0.3095436380624087, 0.4576600409928567)
# (0.478716262442479, 0.3095436380624087, 0.4576600409928567)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.47500000000000003, 0.14500000000000002, 0.55) radius: 0.10500000000000001
# tool pos: (0.47157092177169874, 0.32260516350008445, 0.49482732979255317)
# (0.47157092177169874, 0.32260516350008445, 0.49482732979255317)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.47500000000000003, 0.15, 0.55) radius: 0.11
# tool pos: (0.4717932462632814, 0.3183780935023948, 0.5195961677507837)
# (0.4717932462632814, 0.3183780935023948, 0.5195961677507837)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.47500000000000003, 0.155, 0.55) radius: 0.11499999999999999
# tool pos: (0.4851944291770183, 0.3503096994523042, 0.5050113443656151)
# (0.4851944291770183, 0.3503096994523042, 0.5050113443656151)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.47500000000000003, 0.16, 0.55) radius: 0.12
# tool pos: (0.4857120649774556, 0.3659741306872336, 0.5749423503283934)
# (0.4857120649774556, 0.3659741306872336, 0.5749423503283934)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.5, 0.14, 0.45) radius: 0.1
# tool pos: (0.5184063028684107, 0.28747241523289974, 0.43312464673381873)
# (0.5184063028684107, 0.28747241523289974, 0.43312464673381873)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.5, 0.14500000000000002, 0.45) radius: 0.10500000000000001
# tool pos: (0.4811909991424721, 0.3207779782141922, 0.49240041146611174)
# (0.4811909991424721, 0.3207779782141922, 0.49240041146611174)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.5, 0.15, 0.45) radius: 0.11
# tool pos: (0.5034550369307297, 0.3403659479362505, 0.4953591648613)
# (0.5034550369307297, 0.3403659479362505, 0.4953591648613)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.5, 0.155, 0.45) radius: 0.11499999999999999
# tool pos: (0.5098714386572282, 0.31345834977275683, 0.5226771341339035)
# (0.5098714386572282, 0.31345834977275683, 0.5226771341339035)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.5, 0.16, 0.45) radius: 0.12
# tool pos: (0.5183191162964315, 0.35610277997351736, 0.5737760752501443)
# (0.5183191162964315, 0.35610277997351736, 0.5737760752501443)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.5, 0.14, 0.47500000000000003) radius: 0.1
# tool pos: (0.4755857042092501, 0.3227901671196306, 0.4429989032239182)
# (0.4755857042092501, 0.3227901671196306, 0.4429989032239182)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.5, 0.14500000000000002, 0.47500000000000003) radius: 0.10500000000000001
# tool pos: (0.48358148386307204, 0.32649952812120286, 0.4760518303102065)
# (0.48358148386307204, 0.32649952812120286, 0.4760518303102065)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.5, 0.15, 0.47500000000000003) radius: 0.11
# tool pos: (0.48499982624482, 0.30271689941696267, 0.4759260897230307)
# (0.48499982624482, 0.30271689941696267, 0.4759260897230307)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.5, 0.155, 0.47500000000000003) radius: 0.11499999999999999
# tool pos: (0.486196234403019, 0.349684885167871, 0.5172675840348452)
# (0.486196234403019, 0.349684885167871, 0.5172675840348452)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.5, 0.16, 0.47500000000000003) radius: 0.12
# tool pos: (0.5102207200961766, 0.3664040646732795, 0.5265919464765655)
# (0.5102207200961766, 0.3664040646732795, 0.5265919464765655)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.5, 0.14, 0.5) radius: 0.1
# tool pos: (0.5060739200749882, 0.2882347078248957, 0.4538614294302084)
# (0.5060739200749882, 0.2882347078248957, 0.4538614294302084)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.5, 0.14500000000000002, 0.5) radius: 0.10500000000000001
# tool pos: (0.5217106998962396, 0.30189464106872543, 0.4806982977982948)
# (0.5217106998962396, 0.30189464106872543, 0.4806982977982948)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.5, 0.15, 0.5) radius: 0.11
# tool pos: (0.5044954988177286, 0.3267816401512479, 0.5115061014758385)
# (0.5044954988177286, 0.3267816401512479, 0.5115061014758385)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.5, 0.155, 0.5) radius: 0.11499999999999999
# tool pos: (0.4949110531108046, 0.32559724977398, 0.5104921874487561)
# (0.4949110531108046, 0.32559724977398, 0.5104921874487561)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.5, 0.16, 0.5) radius: 0.12
# tool pos: (0.5222186194991967, 0.32930965029401676, 0.5619775397524645)
# (0.5222186194991967, 0.32930965029401676, 0.5619775397524645)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.5, 0.14, 0.525) radius: 0.1
# tool pos: (0.48637073139866616, 0.30452294043087835, 0.43771782408851967)
# (0.48637073139866616, 0.30452294043087835, 0.43771782408851967)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.5, 0.14500000000000002, 0.525) radius: 0.10500000000000001
# tool pos: (0.49672083127790606, 0.29290145801619377, 0.46558979409970513)
# (0.49672083127790606, 0.29290145801619377, 0.46558979409970513)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.5, 0.15, 0.525) radius: 0.11
# tool pos: (0.49388759196462406, 0.33481717444077297, 0.48398018387798175)
# (0.49388759196462406, 0.33481717444077297, 0.48398018387798175)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.5, 0.155, 0.525) radius: 0.11499999999999999
# tool pos: (0.4783624815731624, 0.3112339364195665, 0.5339696386749284)
# (0.4783624815731624, 0.3112339364195665, 0.5339696386749284)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.5, 0.16, 0.525) radius: 0.12
# tool pos: (0.5018289605554361, 0.3426848422278022, 0.5698335646520172)
# (0.5018289605554361, 0.3426848422278022, 0.5698335646520172)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.5, 0.14, 0.55) radius: 0.1
# tool pos: (0.4858448492199237, 0.3295169473698353, 0.45815391015500506)
# (0.4858448492199237, 0.3295169473698353, 0.45815391015500506)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.5, 0.14500000000000002, 0.55) radius: 0.10500000000000001
# tool pos: (0.4760325499732864, 0.3031661188368575, 0.4879189326918071)
# (0.4760325499732864, 0.3031661188368575, 0.4879189326918071)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.5, 0.15, 0.55) radius: 0.11
# tool pos: (0.4941731947085949, 0.3160008575411234, 0.5044158556776803)
# (0.4941731947085949, 0.3160008575411234, 0.5044158556776803)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.5, 0.155, 0.55) radius: 0.11499999999999999
# tool pos: (0.5064490921795575, 0.3515524227618095, 0.5436325327723698)
# (0.5064490921795575, 0.3515524227618095, 0.5436325327723698)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.5, 0.16, 0.55) radius: 0.12
# tool pos: (0.5149023416956282, 0.33367710174078175, 0.5342817972152977)
# (0.5149023416956282, 0.33367710174078175, 0.5342817972152977)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.525, 0.14, 0.45) radius: 0.1
# tool pos: (0.5343744138193908, 0.3276395828485973, 0.43577538385567793)
# (0.5343744138193908, 0.3276395828485973, 0.43577538385567793)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.525, 0.14500000000000002, 0.45) radius: 0.10500000000000001
# tool pos: (0.5365427903385079, 0.3373685295244462, 0.4626970821297513)
# (0.5365427903385079, 0.3373685295244462, 0.4626970821297513)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.525, 0.15, 0.45) radius: 0.11
# tool pos: (0.5259100356965332, 0.3106655988683741, 0.4762831359027266)
# (0.5259100356965332, 0.3106655988683741, 0.4762831359027266)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.525, 0.155, 0.45) radius: 0.11499999999999999
# tool pos: (0.5212342734375753, 0.3203735037720554, 0.5187084990167113)
# (0.5212342734375753, 0.3203735037720554, 0.5187084990167113)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.525, 0.16, 0.45) radius: 0.12
# tool pos: (0.5138814353147366, 0.3431787712182405, 0.5543392173229085)
# (0.5138814353147366, 0.3431787712182405, 0.5543392173229085)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.525, 0.14, 0.47500000000000003) radius: 0.1
# tool pos: (0.5058765927981017, 0.3231927802961616, 0.4508689553577057)
# (0.5058765927981017, 0.3231927802961616, 0.4508689553577057)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.525, 0.14500000000000002, 0.47500000000000003) radius: 0.10500000000000001
# tool pos: (0.5358429840596297, 0.29660340531725765, 0.4698029851403647)
# (0.5358429840596297, 0.29660340531725765, 0.4698029851403647)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.525, 0.15, 0.47500000000000003) radius: 0.11
# tool pos: (0.5091639918107039, 0.32827106559292546, 0.48224238796716884)
# (0.5091639918107039, 0.32827106559292546, 0.48224238796716884)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.525, 0.155, 0.47500000000000003) radius: 0.11499999999999999
# tool pos: (0.5177806368924978, 0.33440281403244765, 0.5470215972626407)
# (0.5177806368924978, 0.33440281403244765, 0.5470215972626407)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.525, 0.16, 0.47500000000000003) radius: 0.12
# tool pos: (0.5374331809925273, 0.3582662626903482, 0.5701859869872967)
# (0.5374331809925273, 0.3582662626903482, 0.5701859869872967)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.525, 0.14, 0.5) radius: 0.1
# tool pos: (0.5276096234961204, 0.28417112177210097, 0.45422380344778845)
# (0.5276096234961204, 0.28417112177210097, 0.45422380344778845)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.525, 0.14500000000000002, 0.5) radius: 0.10500000000000001
# tool pos: (0.5146073763396275, 0.33809681892736143, 0.4620414389957724)
# (0.5146073763396275, 0.33809681892736143, 0.4620414389957724)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.525, 0.15, 0.5) radius: 0.11
# tool pos: (0.5008214814795737, 0.3050146971132749, 0.5214764658396095)
# (0.5008214814795737, 0.3050146971132749, 0.5214764658396095)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.525, 0.155, 0.5) radius: 0.11499999999999999
# tool pos: (0.5392576456011569, 0.3434958273295454, 0.5140865052876975)
# (0.5392576456011569, 0.3434958273295454, 0.5140865052876975)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.525, 0.16, 0.5) radius: 0.12
# tool pos: (0.503197763306049, 0.34932050830931627, 0.5492813797967312)
# (0.503197763306049, 0.34932050830931627, 0.5492813797967312)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.525, 0.14, 0.525) radius: 0.1
# tool pos: (0.5438252622658296, 0.32887475698722235, 0.44190794759184227)
# (0.5438252622658296, 0.32887475698722235, 0.44190794759184227)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.525, 0.14500000000000002, 0.525) radius: 0.10500000000000001
# tool pos: (0.5115850813235603, 0.33807850772707493, 0.4974659411207841)
# (0.5115850813235603, 0.33807850772707493, 0.4974659411207841)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.525, 0.15, 0.525) radius: 0.11
# tool pos: (0.5399601293676196, 0.3470688852353249, 0.5065223968433396)
# (0.5399601293676196, 0.3470688852353249, 0.5065223968433396)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.525, 0.155, 0.525) radius: 0.11499999999999999
# tool pos: (0.5146510142253898, 0.3537143983312473, 0.5424471777656459)
# (0.5146510142253898, 0.3537143983312473, 0.5424471777656459)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.525, 0.16, 0.525) radius: 0.12
# tool pos: (0.500661842887945, 0.35089383459587614, 0.542361675896611)
# (0.500661842887945, 0.35089383459587614, 0.542361675896611)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.525, 0.14, 0.55) radius: 0.1
# tool pos: (0.5490914694909127, 0.2874070430474083, 0.4489185153519994)
# (0.5490914694909127, 0.2874070430474083, 0.4489185153519994)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.525, 0.14500000000000002, 0.55) radius: 0.10500000000000001
# tool pos: (0.5319736258199362, 0.3148695682749331, 0.4684292303064809)
# (0.5319736258199362, 0.3148695682749331, 0.4684292303064809)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.525, 0.15, 0.55) radius: 0.11
# tool pos: (0.5411058866597123, 0.30684501358427996, 0.4844923955951379)
# (0.5411058866597123, 0.30684501358427996, 0.4844923955951379)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.525, 0.155, 0.55) radius: 0.11499999999999999
# tool pos: (0.5112158514487369, 0.33556594912732274, 0.5048922242247017)
# (0.5112158514487369, 0.33556594912732274, 0.5048922242247017)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.525, 0.16, 0.55) radius: 0.12
# tool pos: (0.5486459744511565, 0.3631095758710841, 0.5730417329031501)
# (0.5486459744511565, 0.3631095758710841, 0.5730417329031501)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.55, 0.14, 0.45) radius: 0.1
# tool pos: (0.563702366634932, 0.32532777496105897, 0.4416572576014321)
# (0.563702366634932, 0.32532777496105897, 0.4416572576014321)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.55, 0.14500000000000002, 0.45) radius: 0.10500000000000001
# tool pos: (0.5453620585706904, 0.2940550694993998, 0.46161170710854715)
# (0.5453620585706904, 0.2940550694993998, 0.46161170710854715)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.55, 0.15, 0.45) radius: 0.11
# tool pos: (0.5276713590893413, 0.30662438173789913, 0.511279718210529)
# (0.5276713590893413, 0.30662438173789913, 0.511279718210529)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.55, 0.155, 0.45) radius: 0.11499999999999999
# tool pos: (0.5635290374251388, 0.3105713729312515, 0.5073473322700188)
# (0.5635290374251388, 0.3105713729312515, 0.5073473322700188)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.55, 0.16, 0.45) radius: 0.12
# tool pos: (0.5294801517119303, 0.32397610412933775, 0.5586023903676958)
# (0.5294801517119303, 0.32397610412933775, 0.5586023903676958)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.55, 0.14, 0.47500000000000003) radius: 0.1
# tool pos: (0.546026973334005, 0.29226836049264227, 0.4528684395661959)
# (0.546026973334005, 0.29226836049264227, 0.4528684395661959)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.55, 0.14500000000000002, 0.47500000000000003) radius: 0.10500000000000001
# tool pos: (0.5613522131355665, 0.3330275586914397, 0.4635163952619358)
# (0.5613522131355665, 0.3330275586914397, 0.4635163952619358)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.55, 0.15, 0.47500000000000003) radius: 0.11
# tool pos: (0.5277687160210599, 0.30657413996455635, 0.4900799317240471)
# (0.5277687160210599, 0.30657413996455635, 0.4900799317240471)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.55, 0.155, 0.47500000000000003) radius: 0.11499999999999999
# tool pos: (0.547807028340024, 0.32310590746198387, 0.534164066777384)
# (0.547807028340024, 0.32310590746198387, 0.534164066777384)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.55, 0.16, 0.47500000000000003) radius: 0.12
# tool pos: (0.5391759423291084, 0.3547812722819428, 0.543996347795006)
# (0.5391759423291084, 0.3547812722819428, 0.543996347795006)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.55, 0.14, 0.5) radius: 0.1
# tool pos: (0.564427275615326, 0.2890575480868452, 0.42784240382166205)
# (0.564427275615326, 0.2890575480868452, 0.42784240382166205)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.55, 0.14500000000000002, 0.5) radius: 0.10500000000000001
# tool pos: (0.5639347697970553, 0.32484986208624933, 0.4888703780924377)
# (0.5639347697970553, 0.32484986208624933, 0.4888703780924377)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.55, 0.15, 0.5) radius: 0.11
# tool pos: (0.5436906568966281, 0.31297112821726775, 0.5043799817598195)
# (0.5436906568966281, 0.31297112821726775, 0.5043799817598195)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.55, 0.155, 0.5) radius: 0.11499999999999999
# tool pos: (0.5435426399608945, 0.3236410951212233, 0.509852714009282)
# (0.5435426399608945, 0.3236410951212233, 0.509852714009282)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.55, 0.16, 0.5) radius: 0.12
# tool pos: (0.5272306150627057, 0.3429927941878003, 0.5649897942285309)
# (0.5272306150627057, 0.3429927941878003, 0.5649897942285309)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.55, 0.14, 0.525) radius: 0.1
# tool pos: (0.5509417574415764, 0.28384782234933165, 0.4403405049772598)
# (0.5509417574415764, 0.28384782234933165, 0.4403405049772598)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.55, 0.14500000000000002, 0.525) radius: 0.10500000000000001
# tool pos: (0.5729716670416714, 0.31887714744156875, 0.4822785122228002)
# (0.5729716670416714, 0.31887714744156875, 0.4822785122228002)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.55, 0.15, 0.525) radius: 0.11
# tool pos: (0.5465201219754031, 0.3017681217877745, 0.5005008426159125)
# (0.5465201219754031, 0.3017681217877745, 0.5005008426159125)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.55, 0.155, 0.525) radius: 0.11499999999999999
# tool pos: (0.5590696255301919, 0.3368088747351725, 0.5138798048865884)
# (0.5590696255301919, 0.3368088747351725, 0.5138798048865884)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.55, 0.16, 0.525) radius: 0.12
# tool pos: (0.5446337838273547, 0.32644302827331595, 0.5728202861397975)
# (0.5446337838273547, 0.32644302827331595, 0.5728202861397975)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.55, 0.14, 0.55) radius: 0.1
# tool pos: (0.5701991977464119, 0.2893565445875423, 0.4521902975038663)
# (0.5701991977464119, 0.2893565445875423, 0.4521902975038663)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.55, 0.14500000000000002, 0.55) radius: 0.10500000000000001
# tool pos: (0.5691020705114945, 0.3128455710822883, 0.47293019808842934)
# (0.5691020705114945, 0.3128455710822883, 0.47293019808842934)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.55, 0.15, 0.55) radius: 0.11
# tool pos: (0.5449512660851551, 0.33620838183057716, 0.5202022196450479)
# (0.5449512660851551, 0.33620838183057716, 0.5202022196450479)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.55, 0.155, 0.55) radius: 0.11499999999999999
# tool pos: (0.5599811027125259, 0.3445012510095613, 0.516386020077856)
# (0.5599811027125259, 0.3445012510095613, 0.516386020077856)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.55, 0.16, 0.55) radius: 0.12
# tool pos: (0.5568030527723571, 0.3578389321368444, 0.5370010136689856)
# (0.5568030527723571, 0.3578389321368444, 0.5370010136689856)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# MoviePy - Building file ./datasets/0212_Roll/init/vis_all.gif with imageio.

# %%
import matplotlib.pyplot as plt
from imitation.env_spec import set_render_mode
env.taichi_env.renderer.update_camera((0.5, 0.15, 0.45), 0., -0.8, 0.8)
set_render_mode(env, 'Roll-v1', 'mesh')
# taichi_env.renderer.verbose = True
img = taichi_env.render(mode='rgb', img_size=128)
plt.imshow(img[:, :, :3])
# taichi_env.render(mode='human', img_size=256)

# %%
taichi_env.primitives[1].position.to_numpy()
# Out:
# array([[0.28, 0.04, 0.5 ],
#        [0.28, 0.04, 0.5 ],
#        [0.28, 0.04, 0.5 ],
#        ...,
#        [0.  , 0.  , 0.  ],
#        [0.  , 0.  , 0.  ],
#        [0.  , 0.  , 0.  ]], dtype=float32)

# %%
import lzma
import pickle
import numpy as np
import os
from plb.utils.visualization_utils import save_numpy_as_gif
from imitation.env_spec import set_render_mode
from scipy.spatial.transform import Rotation as R

np.random.seed(0)
from plb.envs.multitask_env import MultitaskPlasticineEnv
env = MultitaskPlasticineEnv(cfg_path=f'roll.yml')
set_render_mode(env, 'Roll-v1', 'mesh')
taichi_env = env.taichi_env
gifpath = os.path.join(target_path, 'vis_init.gif')
imgs = []
obs = []
reset_target = env.reset()
for i in range(50):
    ob, _, _, _ = env.step([0,0,0,0,0, 10])
    obs.append(ob)
    img = taichi_env.render(mode='rgb', img_size=256)
    imgs.append(img)
save_numpy_as_gif(np.array(imgs)[:, :, :, :3], gifpath)
from IPython.display import Image
Image(gifpath)
# Out:
# Setting pykeops dir to  ~/.cache/pykeops_2080/
# [Taichi] Starting on arch=cuda
# [Tina] version 0.1.1
# [Tina] Taichi properties hacked
# pimirives: num primitive: 2
# Building primitive
# action:
#   dim: 6
#   scale: (0.05, 0.05, 0.05, 0.0, 0.05, 0.05)
# collision_group: [0, 1]
# color: (0.7568, 0.6039, 0.4196)
# friction: 0.9
# h: 0.3
# init_pos: (0.32, 0.25, 0.5)
# init_rot: (0.707, 0.707, 0.0, 0.0)
# lower_bound: (0.0, 0.16, 0.0)
# r: 0.03
# shape: RollingPinExt
# upper_bound: (1.0, 1.0, 1.0)
# variations: None
# Building primitive
# action:
#   dim: 0
#   scale: ()
# collision_group: [0.0, 0.0, 0.0]
# color: (0.5, 0.5, 0.5)
# friction: 5.0
# init_pos: (0.28, 0.04, 0.5)
# init_rot: (1.0, 0.0, 0.0, 0.0)
# lower_bound: (0.0, 0.0, 0.0)
# shape: Box
# size: (0.7, 0.02, 0.43)
# upper_bound: (1.0, 1.0, 1.0)
# variations: None
# Initialize Tina Renderer
# bake_size: 6
# cam_center: (0.3, 0.2, 0.5)
# cam_phi: -0.6
# cam_radius: 1.5
# cam_theta: 0.0
# camera_pos: (0.5, 1.2, 4.0)
# camera_rot: (0.2, 0)
# dx: 0.006666666666666667
# image_res: (128, 128)
# light_direction: (0.0, 1.0, 1.0)
# max_num_particles: 1000000
# max_ray_depth: 2
# mesh: False
# name: tina
# sdf_threshold: 0.20720000000000002
# spp: 50
# target_res: (64, 64, 64)
# tina_img_res: 512
# use_directional_light: True
# use_roulette: False
# voxel_res: (168, 168, 168)
# [Tina] Hint: MMB to orbit, Shift+MMB to pan, wheel to zoom
# Env reseting to: datasets/1006_Roll/target/target_44.npy, init v: 0, target v: 44
# emd after reset: 0.09845858812332153
# ======================WARNING: contact loss mask not set================
# Env reseting to: datasets/1006_Roll/target/target_24.npy, init v: 0, target v: 24
# emd after reset: 0.099650539457798
# ======================WARNING: contact loss mask not set================
# MoviePy - Building file ./datasets/1006_Roll/init/vis_init.gif with imageio.

# %%
print(reset_target[-13:-9])
print(taichi_env.primitives[0].inv_action(ob[-16:-9], reset_target[-16:-9]))
ob, _, _, _ = env.step(taichi_env.primitives[0].inv_action(obs[-1][-16:-9], reset_target[-16:-9]))
print(obs[-1][-16:-9])
# Out:
# [0.707 0.707 0.    0.   ]
# called inverse action !!!!
# [  0.       0.       0.       0.      58.8319 -16.3911]
# called inverse action !!!!
# [ 0.32   0.25   0.5    0.223  0.223  0.671 -0.671]
