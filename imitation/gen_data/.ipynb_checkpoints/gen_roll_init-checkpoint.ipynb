# %%
# %load_ext autoreload
# %autoreload 2
# %cd '~/carl/research/dev/PlasticineLab'
# %pwd
# %matplotlib inline
import matplotlib.pyplot as plt
import taichi as ti
import numpy as np
import cv2
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "2"
from plb.utils.visualization_utils import save_rgb
target_path = './datasets/0125_Roll/init'
if not os.path.exists(target_path):
    os.makedirs(target_path, exist_ok=True)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# /home/jianrenw/carl/research/dev/PlasticineLab

# %%
import lzma
import pickle
import numpy as np
import os
from plb.utils.visualization_utils import save_numpy_as_gif
from imitation.env_spec import set_render_mode
np.random.seed(0)
from plb.envs.multitask_env import MultitaskPlasticineEnv
env = MultitaskPlasticineEnv(cfg_path=f'roll_test2.yml', generating_cached_state=True)
set_render_mode(env, 'Roll-v1', 'mesh')
taichi_env = env.taichi_env

N = 5
xs = np.linspace(0.45, 0.55, N)
zs = np.linspace(0.45, 0.55, N)

def randomize_tool_state(cfg, box_min_x, pin_min_y):
    # No change on the init position of the box
#         pos = eval(cfg.PRIMITIVES[1]['init_pos'])
#         box_dist = np.random.rand() * 0.1 + 0.05
#         cfg.PRIMITIVES[1]['init_pos'] = (float(box_min_x + box_dist), pos[1], pos[2])

    pos = eval(cfg.PRIMITIVES[0]['init_pos'])
    height = np.random.rand() * 0.05
    # height = 0.01
    x_shift = np.random.rand() * 0.1 - 0.05
    z_shift = np.random.rand() * 0.05 - 0.025
    new_pos = (float(xs[i] + x_shift), float(pin_min_y+height), float(zs[k] + z_shift))
    # new_pos = (0.273, 0.2588, 0.5)
    print("tool pos:", new_pos)

    cfg.PRIMITIVES[0]['init_pos'] = new_pos
    print(new_pos)


def case1(cfg): # Sphere
    rs = np.linspace(0.08, 0.10, N)
    # print('setting x pos {}, radius {}'.format(xs[i], rs[j]))
    pos = eval(cfg.SHAPES[0]['init_pos'])
#     cfg.SHAPES[0]['shape'] = 'sphere'
#     del cfg.SHAPES[0]['width']
    cfg.SHAPES[0]['radius'] = rs[j]
    new_pos = (xs[i], rs[j] + 0.04, zs[k])
    print('case1 new pos:', new_pos, 'radius:', rs[j]) 
    cfg.SHAPES[0]['init_pos'] = new_pos
    randomize_tool_state(cfg, 0, rs[j]*2+0.04+0.04)

def case11(cfg): # Sphere on initial place
    rs = np.linspace(0.04, 0.07, N)
    # print('setting x pos {}, radius {}'.format(xs[i], rs[j]))
    pos = eval(cfg.SHAPES[0]['init_pos'])
    cfg.SHAPES[0]['shape'] = 'sphere'
#     del cfg.SHAPES[0]['width']
    cfg.SHAPES[0]['radius'] = rs[j]
    new_pos = (pos[0], rs[j] + 0.03, pos[2])
    cfg.SHAPES[0]['init_pos'] = new_pos    

    randomize_tool_state(cfg, xs[i] + rs[j], rs[j]*2 + 0.1)
    
def case2(cfg): # Capsule
    rs = np.linspace(0.04, 0.06, N)
    capsule_h = 0.2
    # print('setting x pos {}, radius {}, height {}'.format(xs[i], rs[j], capsule_h))

    pos = eval(cfg.SHAPES[0]['init_pos'])
    cfg.SHAPES[0]['shape'] = 'capsule'
    del cfg.SHAPES[0]['width']
    cfg.SHAPES[0]['radius'] = rs[j]
    cfg.SHAPES[0]['height'] = capsule_h
    new_pos = (pos[0], rs[j] + 0.01, pos[2])
    cfg.SHAPES[0]['init_pos'] = new_pos

    randomize_tool_state(cfg, xs[i] + rs[j], 0.19)

def case3(cfg):
    cfg.SHAPES[0]['shape'] = 'box'
    w = np.linspace(0.15, 0.25, N)
    h = np.linspace(0.03, 0.06, N)
    w_id, h_id = np.random.randint(0, N),  np.random.randint(0, N)
    pos = eval(cfg.SHAPES[0]['init_pos'])
    size = eval(cfg.SHAPES[0]['width'])
    new_pos = (xs[i], h[h_id] + 0.1, pos[2])
    new_size = (w[w_id], h[h_id], size[2])
    cfg.SHAPES[0]['init_pos'] = new_pos
    cfg.SHAPES[0]['width'] = new_size
    randomize_tool_state(cfg, xs[i] + w[w_id], 0.19)

def case4(cfg):
    rs = np.linspace(0.04, 0.07, N)
    # print('setting x pos {}, radius {}'.format(xs[i], rs[j]))
    pos = eval(cfg.SHAPES[0]['init_pos'])
#     cfg.SHAPES[0]['shape'] = 'sphere'
#     del cfg.SHAPES[0]['width']
    cfg.SHAPES[0]['radius'] = 0.07
    new_pos = (0.42, 0.11, 0.5)
    print('case1 new pos:', new_pos) 
    cfg.SHAPES[0]['init_pos'] = new_pos
    randomize_tool_state(cfg, xs[i] + rs[j], rs[j]*2+0.04)


target_id =0 
target_imgs = []
gifpath = os.path.join(target_path, 'vis_all.gif')
# for case_id, case in enumerate([case1, case11]):
for case_id, case in enumerate([case1]):
    for i in range(N):
        for j in range(N):
            for k in range(N):
                env.reset(target_cfg_modifier=case)
                img = taichi_env.render(mode='rgb', img_size=128)
                state = taichi_env.get_state()
                state_name = os.path.join(target_path, f'state_{target_id}.xz')
                with lzma.open(state_name, 'wb') as f:
                    pickle.dump(state, f, protocol=4)
                save_rgb(os.path.join(target_path, f'state_{target_id}.png'), np.array(img[:, :, :3]).astype(np.float32))
                target_id += 1
                target_imgs.append(img)
save_numpy_as_gif(np.array(target_imgs)[:, :, :, :3], gifpath)
from IPython.display import Image
Image(gifpath)
# Out:
# pimirives: num primitive: 2
# Building primitive
# action:
#   dim: 6
#   scale: (0.7, 0.05, 0.005, 0.005, 0.0, 0.0)
# collision_group: [0.0, 0.0, 0.0]
# color: (1, 0.0, 0.0)
# friction: 0.9
# h: 0.23
# init_pos: (0.5, 0.25, 0.45)
# init_rot: (0.707, 0.707, 0.0, 0.0)
# lower_bound: (0.0, 0.04, 0.0)
# r: 0.04
# shape: RollingPinExt
# upper_bound: (1.0, 1.0, 1.0)
# variations: None
# Building primitive
# action:
#   dim: 0
#   scale: ()
# collision_group: [0.0, 0.0, 0.0]
# color: (0.5, 0.5, 0.5)
# friction: 5.0
# init_pos: (0.5, 0.02, 0.45)
# init_rot: (1.0, 0.0, 0.0, 0.0)
# lower_bound: (0.0, 0.0, 0.0)
# shape: Box
# size: (0.5, 0.02, 0.45)
# upper_bound: (1.0, 1.0, 1.0)
# variations: None
# Initialize Tina Renderer
# bake_size: 6
# cam_center: (0.5, 0.2, 0.45)
# cam_phi: -0.8
# cam_radius: 0.8
# cam_theta: 0.0
# camera_pos: (0.5, 1.2, 4.0)
# camera_rot: (0.2, 0)
# dx: 0.006666666666666667
# image_res: (128, 128)
# light_direction: (0.0, 1.0, 1.0)
# max_num_particles: 1000000
# max_ray_depth: 2
# mesh: False
# name: tina
# sdf_threshold: 0.20720000000000002
# spp: 50
# target_res: (64, 64, 64)
# tina_img_res: 512
# use_directional_light: True
# use_roulette: False
# voxel_res: (168, 168, 168)
# Cached state path already exists. Deleting datasets/0125_Roll? [y/N]
#  y
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.45, 0

# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.525, 0.135, 0.47500000000000003) radius: 0.095
# tool pos: (0.4981701626471205, 0.31807850772707497, 0.4974659411207841)
# (0.4981701626471205, 0.31807850772707497, 0.4974659411207841)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.525, 0.135, 0.5) radius: 0.095
# tool pos: (0.5549202587352392, 0.31706888523532495, 0.5065223968433396)
# (0.5549202587352392, 0.31706888523532495, 0.5065223968433396)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.525, 0.135, 0.525) radius: 0.095
# tool pos: (0.5043020284507796, 0.31371439833124737, 0.5424471777656459)
# (0.5043020284507796, 0.31371439833124737, 0.5424471777656459)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.525, 0.135, 0.55) radius: 0.095
# tool pos: (0.47632368577588996, 0.3008938345958762, 0.542361675896611)
# (0.47632368577588996, 0.3008938345958762, 0.542361675896611)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.525, 0.14, 0.45) radius: 0.1
# tool pos: (0.5731829389818254, 0.2874070430474083, 0.4489185153519994)
# (0.5731829389818254, 0.2874070430474083, 0.4489185153519994)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.525, 0.14, 0.47500000000000003) radius: 0.1
# tool pos: (0.5389472516398723, 0.30486956827493317, 0.4684292303064809)
# (0.5389472516398723, 0.30486956827493317, 0.4684292303064809)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.525, 0.14, 0.5) radius: 0.1
# tool pos: (0.5572117733194246, 0.28684501358428, 0.4844923955951379)
# (0.5572117733194246, 0.28684501358428, 0.4844923955951379)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.525, 0.14, 0.525) radius: 0.1
# tool pos: (0.49743170289747396, 0.3055659491273228, 0.5048922242247017)
# (0.49743170289747396, 0.3055659491273228, 0.5048922242247017)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.525, 0.14, 0.55) radius: 0.1
# tool pos: (0.572291948902313, 0.3231095758710842, 0.5730417329031501)
# (0.572291948902313, 0.3231095758710842, 0.5730417329031501)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.55, 0.12, 0.45) radius: 0.08
# tool pos: (0.577404733269864, 0.285327774961059, 0.4416572576014321)
# (0.577404733269864, 0.285327774961059, 0.4416572576014321)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.55, 0.12, 0.47500000000000003) radius: 0.08
# tool pos: (0.5407241171413808, 0.24405506949939987, 0.46161170710854715)
# (0.5407241171413808, 0.24405506949939987, 0.46161170710854715)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.55, 0.12, 0.5) radius: 0.08
# tool pos: (0.5053427181786826, 0.24662438173789916, 0.511279718210529)
# (0.5053427181786826, 0.24662438173789916, 0.511279718210529)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.55, 0.12, 0.525) radius: 0.08
# tool pos: (0.5770580748502777, 0.24057137293125158, 0.5073473322700188)
# (0.5770580748502777, 0.24057137293125158, 0.5073473322700188)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.55, 0.12, 0.55) radius: 0.08
# tool pos: (0.5089603034238606, 0.24397610412933782, 0.5586023903676958)
# (0.5089603034238606, 0.24397610412933782, 0.5586023903676958)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.55, 0.125, 0.45) radius: 0.085
# tool pos: (0.5420539466680099, 0.26226836049264224, 0.4528684395661959)
# (0.5420539466680099, 0.26226836049264224, 0.4528684395661959)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.55, 0.125, 0.47500000000000003) radius: 0.085
# tool pos: (0.5727044262711328, 0.2930275586914397, 0.4635163952619358)
# (0.5727044262711328, 0.2930275586914397, 0.4635163952619358)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.55, 0.125, 0.5) radius: 0.085
# tool pos: (0.5055374320421199, 0.25657413996455636, 0.4900799317240471)
# (0.5055374320421199, 0.25657413996455636, 0.4900799317240471)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.55, 0.125, 0.525) radius: 0.085
# tool pos: (0.545614056680048, 0.2631059074619839, 0.534164066777384)
# (0.545614056680048, 0.2631059074619839, 0.534164066777384)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.55, 0.125, 0.55) radius: 0.085
# tool pos: (0.5283518846582167, 0.28478127228194283, 0.543996347795006)
# (0.5283518846582167, 0.28478127228194283, 0.543996347795006)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.55, 0.13, 0.45) radius: 0.09
# tool pos: (0.5788545512306519, 0.2690575480868452, 0.42784240382166205)
# (0.5788545512306519, 0.2690575480868452, 0.42784240382166205)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.55, 0.13, 0.47500000000000003) radius: 0.09
# tool pos: (0.5778695395941104, 0.29484986208624936, 0.4888703780924377)
# (0.5778695395941104, 0.29484986208624936, 0.4888703780924377)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.55, 0.13, 0.5) radius: 0.09
# tool pos: (0.5373813137932562, 0.27297112821726777, 0.5043799817598195)
# (0.5373813137932562, 0.27297112821726777, 0.5043799817598195)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.55, 0.13, 0.525) radius: 0.09
# tool pos: (0.5370852799217889, 0.27364109512122337, 0.509852714009282)
# (0.5370852799217889, 0.27364109512122337, 0.509852714009282)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.55, 0.13, 0.55) radius: 0.09
# tool pos: (0.5044612301254114, 0.2829927941878004, 0.5649897942285309)
# (0.5044612301254114, 0.2829927941878004, 0.5649897942285309)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.55, 0.135, 0.45) radius: 0.095
# tool pos: (0.5518835148831527, 0.27384782234933164, 0.4403405049772598)
# (0.5518835148831527, 0.27384782234933164, 0.4403405049772598)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.55, 0.135, 0.47500000000000003) radius: 0.095
# tool pos: (0.5959433340833425, 0.2988771474415688, 0.4822785122228002)
# (0.5959433340833425, 0.2988771474415688, 0.4822785122228002)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.55, 0.135, 0.5) radius: 0.095
# tool pos: (0.5430402439508062, 0.27176812178777454, 0.5005008426159125)
# (0.5430402439508062, 0.27176812178777454, 0.5005008426159125)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.55, 0.135, 0.525) radius: 0.095
# tool pos: (0.5681392510603839, 0.2968088747351726, 0.5138798048865884)
# (0.5681392510603839, 0.2968088747351726, 0.5138798048865884)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.55, 0.135, 0.55) radius: 0.095
# tool pos: (0.5392675676547095, 0.276443028273316, 0.5728202861397975)
# (0.5392675676547095, 0.276443028273316, 0.5728202861397975)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.55, 0.14, 0.45) radius: 0.1
# tool pos: (0.5903983954928238, 0.2893565445875423, 0.4521902975038663)
# (0.5903983954928238, 0.2893565445875423, 0.4521902975038663)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.55, 0.14, 0.47500000000000003) radius: 0.1
# tool pos: (0.588204141022989, 0.3028455710822883, 0.47293019808842934)
# (0.588204141022989, 0.3028455710822883, 0.47293019808842934)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.55, 0.14, 0.5) radius: 0.1
# tool pos: (0.5399025321703103, 0.3162083818305772, 0.5202022196450479)
# (0.5399025321703103, 0.3162083818305772, 0.5202022196450479)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.55, 0.14, 0.525) radius: 0.1
# tool pos: (0.5699622054250517, 0.3145012510095614, 0.516386020077856)
# (0.5699622054250517, 0.3145012510095614, 0.516386020077856)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# case1 new pos: (0.55, 0.14, 0.55) radius: 0.1
# tool pos: (0.5636061055447141, 0.3178389321368445, 0.5370010136689856)
# (0.5636061055447141, 0.3178389321368445, 0.5370010136689856)
# Env reset: No initial state during cache generation
# Generating target, skipping setting emd
# emd after reset: 0.0
# ======================WARNING: contact loss mask not set================
# MoviePy - Building file ./datasets/0125_Roll/init/vis_all.gif with imageio.

# %%
import matplotlib.pyplot as plt
from imitation.env_spec import set_render_mode
env.taichi_env.renderer.update_camera((0.5, 0.15, 0.45), 0., -0.8, 0.8)
set_render_mode(env, 'Roll-v1', 'mesh')
# taichi_env.renderer.verbose = True
img = taichi_env.render(mode='rgb', img_size=128)
plt.imshow(img[:, :, :3])
# taichi_env.render(mode='human', img_size=256)

# %%
taichi_env.primitives[1].position.to_numpy()
# Out:
# array([[0.28, 0.04, 0.5 ],
#        [0.28, 0.04, 0.5 ],
#        [0.28, 0.04, 0.5 ],
#        ...,
#        [0.  , 0.  , 0.  ],
#        [0.  , 0.  , 0.  ],
#        [0.  , 0.  , 0.  ]], dtype=float32)

# %%
import lzma
import pickle
import numpy as np
import os
from plb.utils.visualization_utils import save_numpy_as_gif
from imitation.env_spec import set_render_mode
from scipy.spatial.transform import Rotation as R

np.random.seed(0)
from plb.envs.multitask_env import MultitaskPlasticineEnv
env = MultitaskPlasticineEnv(cfg_path=f'roll.yml')
set_render_mode(env, 'Roll-v1', 'mesh')
taichi_env = env.taichi_env
gifpath = os.path.join(target_path, 'vis_init.gif')
imgs = []
obs = []
reset_target = env.reset()
for i in range(50):
    ob, _, _, _ = env.step([0,0,0,0,0, 10])
    obs.append(ob)
    img = taichi_env.render(mode='rgb', img_size=256)
    imgs.append(img)
save_numpy_as_gif(np.array(imgs)[:, :, :, :3], gifpath)
from IPython.display import Image
Image(gifpath)
# Out:
# Setting pykeops dir to  ~/.cache/pykeops_2080/
# [Taichi] Starting on arch=cuda
# [Tina] version 0.1.1
# [Tina] Taichi properties hacked
# pimirives: num primitive: 2
# Building primitive
# action:
#   dim: 6
#   scale: (0.05, 0.05, 0.05, 0.0, 0.05, 0.05)
# collision_group: [0, 1]
# color: (0.7568, 0.6039, 0.4196)
# friction: 0.9
# h: 0.3
# init_pos: (0.32, 0.25, 0.5)
# init_rot: (0.707, 0.707, 0.0, 0.0)
# lower_bound: (0.0, 0.16, 0.0)
# r: 0.03
# shape: RollingPinExt
# upper_bound: (1.0, 1.0, 1.0)
# variations: None
# Building primitive
# action:
#   dim: 0
#   scale: ()
# collision_group: [0.0, 0.0, 0.0]
# color: (0.5, 0.5, 0.5)
# friction: 5.0
# init_pos: (0.28, 0.04, 0.5)
# init_rot: (1.0, 0.0, 0.0, 0.0)
# lower_bound: (0.0, 0.0, 0.0)
# shape: Box
# size: (0.7, 0.02, 0.43)
# upper_bound: (1.0, 1.0, 1.0)
# variations: None
# Initialize Tina Renderer
# bake_size: 6
# cam_center: (0.3, 0.2, 0.5)
# cam_phi: -0.6
# cam_radius: 1.5
# cam_theta: 0.0
# camera_pos: (0.5, 1.2, 4.0)
# camera_rot: (0.2, 0)
# dx: 0.006666666666666667
# image_res: (128, 128)
# light_direction: (0.0, 1.0, 1.0)
# max_num_particles: 1000000
# max_ray_depth: 2
# mesh: False
# name: tina
# sdf_threshold: 0.20720000000000002
# spp: 50
# target_res: (64, 64, 64)
# tina_img_res: 512
# use_directional_light: True
# use_roulette: False
# voxel_res: (168, 168, 168)
# [Tina] Hint: MMB to orbit, Shift+MMB to pan, wheel to zoom
# Env reseting to: datasets/1006_Roll/target/target_44.npy, init v: 0, target v: 44
# emd after reset: 0.09845858812332153
# ======================WARNING: contact loss mask not set================
# Env reseting to: datasets/1006_Roll/target/target_24.npy, init v: 0, target v: 24
# emd after reset: 0.099650539457798
# ======================WARNING: contact loss mask not set================
# MoviePy - Building file ./datasets/1006_Roll/init/vis_init.gif with imageio.

# %%
print(reset_target[-13:-9])
print(taichi_env.primitives[0].inv_action(ob[-16:-9], reset_target[-16:-9]))
ob, _, _, _ = env.step(taichi_env.primitives[0].inv_action(obs[-1][-16:-9], reset_target[-16:-9]))
print(obs[-1][-16:-9])
# Out:
# [0.707 0.707 0.    0.   ]
# called inverse action !!!!
# [  0.       0.       0.       0.      58.8319 -16.3911]
# called inverse action !!!!
# [ 0.32   0.25   0.5    0.223  0.223  0.671 -0.671]
